# %% [markdown]
# <a href="https://colab.research.google.com/github/vitorjensen/Data-Science-para-Marketing/blob/main/Aula_01_Conhecendo_os_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome_influenciador = "Vitor"
print(nome_influenciador)
# Out:
# Vitor

# %%
import pandas as pd
import seaborn as sns

# %%
campanha = pd.read_csv("/content/campanha.csv")

# %%
campanha.shape
# Out:
# (50000, 8)

# %%
campanha.head()
# Out:
#    Id_campanha  impressoes  cliques       canal  custo  receita estado    pais
# 0            1      152431     9462       Email  13258    32309     MG  Brasil
# 1            1       39688     3218         PPC  16391    16568     BA  Brasil
# 2            1      104506     4756  Google Ads   6189    19029     AL  Brasil
# 3            1       80768     3566  Google Ads   5215        0     PI  Brasil
# 4            1       54932     3645  Google Ads  16767     8825     RJ  Brasil

# %%
campanha['canal']
# Out:
# 0               Email
# 1                 PPC
# 2          Google Ads
# 3          Google Ads
# 4          Google Ads
#              ...
# 49995    Social Media
# 49996      Google Ads
# 49997      Google Ads
# 49998             PPC
# 49999        Meta Ads
# Name: canal, Length: 50000, dtype: object

# %%
campanha['canal'].unique()
# Out:
# array(['Email', 'PPC', 'Google Ads', 'Meta Ads', 'Social Media'],
#       dtype=object)

# %%
campanha['canal'].value_counts()
# Out:
# canal
# Google Ads      25146
# Meta Ads        15009
# Social Media     4874
# PPC              2526
# Email            2445
# Name: count, dtype: int64

# %% [markdown]
# Calculando a Métrica CTR

# %%
campanha['ctr']=(campanha['cliques']/campanha['impressoes'])*100
campanha.head()
# Out:
#    Id_campanha  impressoes  cliques       canal  custo  receita estado  \
# 0            1      152431     9462       Email  13258    32309     MG
# 1            1       39688     3218         PPC  16391    16568     BA
# 2            1      104506     4756  Google Ads   6189    19029     AL
# 3            1       80768     3566  Google Ads   5215        0     PI
# 4            1       54932     3645  Google Ads  16767     8825     RJ
#
#      pais       ctr
# 0  Brasil  6.207399
# 1  Brasil  8.108244
# 2  Brasil  4.550935
# 3  Brasil  4.415115
# 4  Brasil  6.635477

# %%
campanha["ctr"].describe()
# Out:
# count    50000.000000
# mean         5.148482
# std          1.604119
# min          0.992663
# 25%          4.050781
# 50%          5.132384
# 75%          6.241502
# max         10.000000
# Name: ctr, dtype: float64

# %%
sns.boxplot(campanha["ctr"])
# Out:
# <Axes: ylabel='ctr'>
